# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# In this notebook, the data frame is cleaned using some preprocessing steps as discussed in the data analysis phase. The cleaned data frame is then stored for later use.

# %%
# Import packages
import string

import pandas as pd
import numpy as np

import wordninja

import nlpaug.augmenter.char as nac
import nlpaug.augmenter.word as naw
import nlpaug.augmenter.sentence as nas
import nlpaug.flow as nafc
from nlpaug.util import Action

from sklearn.preprocessing import LabelEncoder

import nltk
nltk.download('wordnet')
nltk.download('averaged_perceptron_tagger')
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\ramra\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\ramra\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\ramra\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# True

# %%
#read the data as a pandas dataframe
df = pd.read_json('../Data/data.json')

# %% [markdown]
# ### Dropping non-english entries

# %% [markdown]
# Since there is a negligible amount of non-english descriptions and titles, I decide to drop them. A language translation model is also available from *sparkNlp* and it is implemented in a seperate notebook.

# %%
# Non-english entries
display(df[166:167])
display(df[146:147])
# Out:
#     level                                        description  \
# 166   NaN  Teads.Tv est spécialisé dans la diffusion de c...
#
#                   title
# 166  Finance Controller
#     level description                                              title
# 146   NaN          no  Praktikant im Bereich Operations & Customer Se...

# %%
# Drop rows with non-english entries
df.drop(index=[146, 166], inplace=True)

# Reset the index.
df.reset_index(inplace=True, drop = True)

# %%
# Split dataframe without labels (levels) as test set and the remaining as train set
test_df = df[df['level'].isnull()]

# Reset the index
test_df.reset_index(inplace = True)

# Drop the test dataframe
df.dropna(inplace = True)

print(f"Test size: {test_df.shape[0]}")
print(f"Train size: {df.shape[0]}")
# Out:
# Test size: 73
# Train size: 141

# %% [markdown]
# ### Split Combined words

# %% [markdown]
# Since some words like "job descriptionInVision" are combined, in this part, the joined words are split.

# %%
def splitwords(text):
    """
    Split combined or joined words from the given list and return the cleaned list.
    """
    text = text.tolist()
    
    for tex in range(0, len(text)):
        temp = wordninja.split(text[tex])
        text[tex] = ' '.join(temp)
    
    return text

# %%
# Split the combined words in the actual dataframe
cleaned_df = pd.DataFrame()

cleaned_df['description'] = splitwords(df.description)
cleaned_df['title'] = splitwords(df.title)
cleaned_df['level'] = df.level

# %%
# For the test set
cleaned_test_df = pd.DataFrame()

cleaned_test_df['description'] = splitwords(test_df.description)
cleaned_test_df['title'] = splitwords(test_df.title)

# %%
cleaned_df[4:10]
# Out:
#                                          description  \
# 4  JOB DESCRIPTION Pa met is looking for a IBM We...
# 5  JOB DESCRIPTION Pa met is looking for a iOS de...
# 6  JOB DESCRIPTION Pa met is looking for a Java D...
# 7  Snap chat is seeking an experienced market res...
# 8  Description In Vision is the world s leading d...
# 9  Description In Vision is the world s leading d...
#
#                                  title         level
# 4      IBM Web Sphere Portal Developer   Entry Level
# 5                        iOS Developer   Entry Level
# 6                       Java Developer   Entry Level
# 7                    Market Researcher  Senior Level
# 8   Senior Full Stack Developer remote  Senior Level
# 9  Enterprise Account Executive remote  Senior Level

# %% [markdown]
# ### Simple Preprocessing Steps

# %%
def preprocessing(df):
    """
    This function does the following preprocessing steps for a given dataframe and returns the cleaned frame.
        1. remove "\n",
        2. replace numbers with words (e.g., "3 years" as "three years"),
        3. remove all special characters,
        4. convert text to lowercase,
        5. remove "description" or "job description" or "Job Purpose" or "No description available",
        6. replace abbreviations (e.g., "sr.", "jr."),
        7. remove trailing white spaces at the beginning and end of the sentence,
        8. remove single characters if available, for example: "m", "f" from (m/f).
    """
    # remove "\n"
    df = df.replace('\n',' ', regex=True)
    
    # decontract words.
    df = df.replace({r"won't":"will not",
                     r"can\'t":"can not", 
                     "n't":" not", 
                     r"\'re":" are",
                     r"\'s":" is",
                     r"\'d":" would",
                     r"\'ll":" will",
                     r"\'t":" not",
                     r"\'ve":" have",
                     r"\'m":" am"}, regex=True)
    
    # replace numbers with the words.
    df = df.replace({'0': ' zero',
       '1': ' one',
       '2': ' two',
       '3': ' three',
       '4': ' four',
       '5': ' five',
       '6': ' six',
       '7': ' seven',
       '8': ' eight',
       '9': ' nine'}, regex=True)
    
    # remove special characters
    df = df.replace('[^A-Za-z0-9]+', ' ', regex=True)
    
    # convert to lower case
    df = df.apply(lambda x: x.astype(str).str.lower())
   
    # remove description or job decription at the beginning of the sentence
    df = df.replace(['job description', 'job purpose', 'company description', 'no description available', 'description', 'no'], ' ', regex=True)
    
    # replace abbreviations
    df = df.replace({'sr': 'senior',
                     'jr': 'junior'}, regex=True)

    # remove trailing white spaces
    df['description'] = df['description'].str.rstrip()
    df['description'] = df['description'].str.lstrip()
    
    df['title'] = df['title'].str.rstrip()
    df['title'] = df['title'].str.lstrip()

    # remove single characters
    df['description'] = df['description'].str.replace(r'\b\w\b', ' ').str.replace(r'\s+', ' ')
    df['title'] = df['title'].str.replace(r'\b\w\b', ' ').str.replace(r'\s+', ' ')
    
    return df

# %%
# Preprocess dataframes
cleaned_df = preprocessing(cleaned_df)
cleaned_test_df = preprocessing(cleaned_test_df)
# Out:
# C:\Users\ramra\AppData\Local\Temp/ipykernel_13884/2992338054.py:61: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['description'] = df['description'].str.replace(r'\b\w\b', ' ').str.replace(r'\s+', ' ')
# C:\Users\ramra\AppData\Local\Temp/ipykernel_13884/2992338054.py:62: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['title'] = df['title'].str.replace(r'\b\w\b', ' ').str.replace(r'\s+', ' ')

# %%
cleaned_df[4:10]
# Out:
#                                          description  \
# 4  pa met is looking for ibm web sphere developer...
# 5  pa met is looking for ios developers to join u...
# 6  pa met is looking for java developers to join ...
# 7  snap chat is seeking an experienced market res...
# 8  in vision is the world leading design collabor...
# 9  in vision is the world leading design collabor...
#
#                                  title         level
# 4      ibm web sphere portal developer   entry level
# 5                        ios developer   entry level
# 6                       java developer   entry level
# 7                    market researcher  senior level
# 8   senior full stack developer remote  senior level
# 9  enterprise account executive remote  senior level

# %%
# Combine job title and description
cleaned_df['text'] = cleaned_df["title"] + " " + cleaned_df["description"]
cleaned_test_df['text']=  cleaned_test_df["title"] + " " + cleaned_test_df["description"]

# %%
cleaned_df[4:10]
# Out:
#                                          description  \
# 4  pa met is looking for ibm web sphere developer...
# 5  pa met is looking for ios developers to join u...
# 6  pa met is looking for java developers to join ...
# 7  snap chat is seeking an experienced market res...
# 8  in vision is the world leading design collabor...
# 9  in vision is the world leading design collabor...
#
#                                  title         level  \
# 4      ibm web sphere portal developer   entry level
# 5                        ios developer   entry level
# 6                       java developer   entry level
# 7                    market researcher  senior level
# 8   senior full stack developer remote  senior level
# 9  enterprise account executive remote  senior level
#
#                                                 text
# 4  ibm web sphere portal developer pa met is look...
# 5  ios developer pa met is looking for ios develo...
# 6  java developer pa met is looking for java deve...
# 7  market researcher snap chat is seeking an expe...
# 8  senior full stack developer remote in vision i...
# 9  enterprise account executive remote in vision ...

# %%
cleaned_test_df[0:10]
# Out:
#                                          description  \
# 0  outfitter is europe biggest personal shopping ...
# 1  outfitter is europe biggest personal shopping ...
# 2  outfitter is europe biggest personal shopping ...
# 3  outfitter is europe biggest personal shopping ...
# 4  outfitter is europe biggest personal shopping ...
# 5  outfitter is europe biggest personal shopping ...
# 6  outfitter is europe biggest personal shopping ...
# 7  outfitter is europa is groot ste personal shop...
# 8  outfitter is europe biggest personal shopping ...
# 9  outfitter is europe biggest personal shopping ...
#
#                                      title  \
# 0  customer service netherlands in berlin
# 1                        devo ps engineer
# 2           head of product management it
# 3                       help desk support
# 4                        intern help desk
# 5      sales consultant belgium in berlin
# 6      sales consultant denmark in berlin
# 7              sales consultant in berlin
# 8            sales consultant netherlands
# 9       sales consultant sweden in berlin
#
#                                                 text
# 0  customer service netherlands in berlin  outfit...
# 1  devo ps engineer  outfitter is europe biggest ...
# 2  head of product management it  outfitter is eu...
# 3  help desk support  outfitter is europe biggest...
# 4  intern help desk  outfitter is europe biggest ...
# 5  sales consultant belgium in berlin  outfitter ...
# 6  sales consultant denmark in berlin  outfitter ...
# 7  sales consultant in berlin  outfitter is europ...
# 8  sales consultant netherlands  outfitter is eur...
# 9  sales consultant sweden in berlin  outfitter i...

# %%
# Lets encode the categorical levels to numerical values.
encoder = LabelEncoder()
cleaned_df.level = encoder.fit_transform(cleaned_df.level)

# %%
# Check the frequencies of the classes
(unique, counts) = np.unique(cleaned_df.level, return_counts=True)

frequencies = np.asarray((unique, counts)).T
frequencies
# Out:
# array([[ 0, 37],
#        [ 1, 15],
#        [ 2, 32],
#        [ 3, 57]], dtype=int64)

# %%
#saving the dataframes for the modelling phase.
#cleaned_df.to_pickle("../Data/cleanedpandasDf.pkl") 
#cleaned_test_df.to_pickle("../Data/cleanedpandasDf.parquet")
#cleaned_df.to_parquet("../Data/cleanedpandasDf.pkl") 
#cleaned_test_df.to_parquet("../Data/cleanedpandastestDf.parquet")

# %%
#cleaned_df.to_csv("../Data/cleanedpandasDf.csv")

# %%
#cleaned_test_df.to_csv("../Data/cleanedpandastestDf.csv")

# %% [markdown]
# ### Balancing the dataset

# %% [markdown]
# As noted in the data analysis phase, the data set is imbalanced. The number of entries based on the levels on the train set is:
# 1. entry level: 37
# 2. senior level: 57
# 3. mid level: 32
# 4. Internship: 15
#
# Hence in this part this is addressed by some imbalancing techniques.

# %% [markdown]
# map: {0: Entry_level,
#       1: internships,
#       2: mid-level,
#       3: senior-level}

# %%
# Augment the "description" column of the dataframe.
X = cleaned_df['description']
y = cleaned_df.level

# %%
# Replace 8 random words in the sentence using the wordnet from nltk.
# Augment text by replacing words with synonyms
aug = naw.SynonymAug(aug_src='wordnet',aug_max=8)

# %%
augmented_text=[]
augmented_labels=[]
augmented_title=[]
augmented_description=[]

def append(temps, i, label):
    """
    Append the generated sentences to a list with the corresponding labels, titles and description.
    """
    for sent in temps:
        #print(sent)
        augmented_description.append(sent)        
        augmented_labels.append(label)
        augmented_title.append(cleaned_df['title'][i])
        augmented_text.append(cleaned_df['title'][i] + " " + sent)

def augmentData(X,y):
    
    """
    Augment data using the nlpaug synonymn augmenter. Need n=2, to create two augmented sentences.
    """
    level_two_counter = 0
    level_zero_counter = 0
    
    for i in range(0, X.size):
        #entrylevel
        if (y[i]==0 and level_zero_counter < 6):
            level_zero_counter = level_zero_counter + 1
            temps = aug.augment(X[i], n=2)
            append(temps, i, y[i])
            
        if y[i]==1:
            #internships
            temps = aug.augment(X[i], n=2)
            append(temps, i, y[i])
            
        if (y[i]==2 and level_two_counter < 10):
            #midsenior level
            level_two_counter = level_two_counter + 1
            temps = aug.augment(X[i], n=2)
            append(temps, i, y[i])
        

augmentData(X,y)

# %%
cleaned_df.level = y

# %%
augmentedDf = pd.DataFrame({"description": augmented_description, "title": augmented_title, "text": augmented_text, "level": augmented_labels})

# %%
augmentedDf
# Out:
#                                           description  \
# 0   outfitter is europe biggest personal shopping ...
# 1   outfitter is europe biggest personal shopping ...
# 2   pa met is looking for android developer to joi...
# 3   pa fit is looking for android developer to joi...
# 4   pa met is looking for ibm web sphere developer...
# 5   pa met is looking for ibm web sphere developer...
# 6   pa met is looking for ios developer to join us...
# 7   pa met is looking for ios developers to join u...
# 8   pa met is looking for java developers to join ...
# 9   pa met is looking for java developers to join ...
# 10  we are looking for an infrastructure engineer ...
# 11  we are looking for an infrastructure engineer ...
# 12  we are front for full time frontend developer ...
# 13  we are looking for full time frontend develope...
# 14  the role we re looking for talented and passio...
# 15  the role we re looking for talented and passio...
# 16  about us headquartered in new york and with of...
# 17  about us headquartered in new york and with of...
# 18  trip gator is platform which creates personali...
# 19  trip gator is platform which creates personali...
# 20  outfitter is europe biggest personal shopping ...
# 21  outfitter is europe biggest personal shopping ...
# 22  with bab bel anyone can learn language whether...
# 23  with bab bel anyone can learn language whether...
# 24  we are looking for web mobile frontend and jav...
# 25  we are looking for web mobile frontend and jav...
# 26  uber is expanding quickly throughout asia paci...
# 27  uber is expanding quickly throughout asia paci...
# 28  data center operations designs installs mainta...
# 29  data center operations designs installs mainta...
# 30  located in singapore would you like to be part...
# 31  located in singapore island would you like to ...
# 32  we are unu we believe in cities in which all p...
# 33  we are unu we believe in cities in which all p...
# 34  we are unu we believe in cities in which all p...
# 35  we are unu we believe in cities in which all p...
# 36  we are unu we believe in cities in which all p...
# 37  we are unu we believe in cities in which all p...
# 38  we are unu we believe in cities in which all p...
# 39  we are unu we believe in cities in which all p...
# 40  ux research intern berlin 0 trio market user i...
# 41  ux research intern israel baline zero in three...
# 42  we are unu we believe in cities in which all p...
# 43  we are unu we believe in cities in which all p...
# 44  we are unu we believe in cities in which all p...
# 45  we are unu we believe in cities in which all p...
# 46  you stern have data without information but yo...
# 47  you can have data without information but you ...
# 48  the training team mission is to enable through...
# 49  the grooming team mission is to enable through...
# 50  security is paramount in every it department t...
# 51  security is paramount in every information tec...
# 52  zu beaver state community intern foster city c...
# 53  zu or community of interests intern foster urb...
# 54  founded in two zero zero seven zu or is one of...
# 55  founded in two zero zero seven zu or is one of...
# 56  amazon is wait for passionate talented and ima...
# 57  amazon river is looking for passionate talente...
# 58  certificate and compliance intern foster metro...
# 59  security and compliance intern foster urban ce...
#
#                                                 title  \
# 0                                  frontend engineer
# 1                                  frontend engineer
# 2                                   android developer
# 3                                   android developer
# 4                     ibm web sphere portal developer
# 5                     ibm web sphere portal developer
# 6                                       ios developer
# 7                                       ios developer
# 8                                      java developer
# 9                                      java developer
# 10                        infrastructure engineer aw
# 11                        infrastructure engineer aw
# 12                       frontend engineer full stack
# 13                       frontend engineer full stack
# 14                                     ui ux designer
# 15                                     ui ux designer
# 16                                full stack engineer
# 17                                full stack engineer
# 18                                       backend geek
# 19                                       backend geek
# 20                   intern online marketing denmark
# 21                   intern online marketing denmark
# 22                         talent acquisition manager
# 23                         talent acquisition manager
# 24       software developer javascript cross platform
# 25       software developer javascript cross platform
# 26                 financial operations analyst india
# 27                 financial operations analyst india
# 28  data center technician amazon web services sin...
# 29  data center technician amazon web services sin...
# 30  account manager indonesia territory based in s...
# 31  account manager indonesia territory based in s...
# 32             electrical engineering working student
# 33             electrical engineering working student
# 34                               intern in operations
# 35                               intern in operations
# 36     rapid prototyping working students electronics
# 37     rapid prototyping working students electronics
# 38                              brand campaign intern
# 39                              brand campaign intern
# 40                                 ux research intern
# 41                                 ux research intern
# 42                        business development intern
# 43                        business development intern
# 44        business development intern french speaking
# 45        business development intern french speaking
# 46                      business intelligence intern
# 47                      business intelligence intern
# 48                        instructional design intern
# 49                        instructional design intern
# 50          sales intern enterprise security software
# 51          sales intern enterprise security software
# 52                             zu or community intern
# 53                             zu or community intern
# 54                         recognition rewards intern
# 55                         recognition rewards intern
# 56                             speech science intern
# 57                             speech science intern
# 58                     security and compliance intern
# 59                     security and compliance intern
#
#                                                  text  level
# 0   frontend engineer  outfitter is europe biggest...      0
# 1   frontend engineer  outfitter is europe biggest...      0
# 2   android developer pa met is looking for androi...      0
# 3   android developer pa fit is looking for androi...      0
# 4   ibm web sphere portal developer pa met is look...      0
# 5   ibm web sphere portal developer pa met is look...      0
# 6   ios developer pa met is looking for ios develo...      0
# 7   ios developer pa met is looking for ios develo...      0
# 8   java developer pa met is looking for java deve...      0
# 9   java developer pa met is looking for java deve...      0
# 10  infrastructure engineer aw  we are looking for...      2
# 11  infrastructure engineer aw  we are looking for...      2
# 12  frontend engineer full stack we are front for ...      2
# 13  frontend engineer full stack we are looking fo...      2
# 14  ui ux designer the role we re looking for tale...      2
# 15  ui ux designer the role we re looking for tale...      2
# 16  full stack engineer about us headquartered in ...      2
# 17  full stack engineer about us headquartered in ...      2
# 18  backend geek trip gator is platform which crea...      0
# 19  backend geek trip gator is platform which crea...      0
# 20  intern online marketing denmark  outfitter is ...      1
# 21  intern online marketing denmark  outfitter is ...      1
# 22  talent acquisition manager with bab bel anyone...      2
# 23  talent acquisition manager with bab bel anyone...      2
# 24  software developer javascript cross platform w...      2
# 25  software developer javascript cross platform w...      2
# 26  financial operations analyst india uber is exp...      2
# 27  financial operations analyst india uber is exp...      2
# 28  data center technician amazon web services sin...      2
# 29  data center technician amazon web services sin...      2
# 30  account manager indonesia territory based in s...      2
# 31  account manager indonesia territory based in s...      2
# 32  electrical engineering working student we are ...      1
# 33  electrical engineering working student we are ...      1
# 34  intern in operations we are unu we believe in ...      1
# 35  intern in operations we are unu we believe in ...      1
# 36  rapid prototyping working students electronics...      1
# 37  rapid prototyping working students electronics...      1
# 38  brand campaign intern we are unu we believe in...      1
# 39  brand campaign intern we are unu we believe in...      1
# 40  ux research intern ux research intern berlin 0...      1
# 41  ux research intern ux research intern israel b...      1
# 42  business development intern we are unu we beli...      1
# 43  business development intern we are unu we beli...      1
# 44  business development intern french speaking we...      1
# 45  business development intern french speaking we...      1
# 46  business intelligence intern  you stern have d...      1
# 47  business intelligence intern  you can have dat...      1
# 48  instructional design intern the training team ...      1
# 49  instructional design intern the grooming team ...      1
# 50  sales intern enterprise security software secu...      1
# 51  sales intern enterprise security software secu...      1
# 52  zu or community intern zu beaver state communi...      1
# 53  zu or community intern zu or community of inte...      1
# 54  recognition rewards intern founded in two zero...      1
# 55  recognition rewards intern founded in two zero...      1
# 56  speech science intern  amazon is wait for pass...      1
# 57  speech science intern  amazon river is looking...      1
# 58  security and compliance intern certificate and...      1
# 59  security and compliance intern security and co...      1

# %%
internAugmentedDf = cleaned_df.append(augmentedDf)

# %%
(unique, counts) = np.unique(internAugmentedDf['level'], return_counts=True)
frequencies = np.asarray((unique, counts)).T
frequencies
# Out:
# array([[ 0, 49],
#        [ 1, 45],
#        [ 2, 50],
#        [ 3, 57]], dtype=int64)

# %%
#internAugmentedDf.to_pickle("../Data/cleanedAugmentedPandasDf.pkl")
#internAugmentedDf.to_parquet("../Data/cleanedAugmentedPandasDf.parquet")

# %%
#internAugmentedDf.to_csv("../Data/cleanedAugmentedPandasDf.csv")
